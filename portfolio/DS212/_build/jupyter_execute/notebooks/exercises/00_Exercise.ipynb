# %% [markdown]
# # **Exercise**
#
# ## **What Programming Paradigm Am I?**
#
# **Learning Objective**
#
# Given a description of how a programmer approaches a problem, identify the programming paradigm being demonstrated and briefly justify the answer.
#
# Choose from:
#
# **Imperative · Procedural · Object-Oriented · Functional · Declarative**
#
# > **Instruction:** Identify the paradigm that is **most strongly emphasized** in each scenario. Some real programs combine multiple paradigms, but choose the best answer based on the description.

# %% [markdown]
# ### **Scenario 1 — Processing Sensor Data**
#
# A weather station receives a list of temperature readings. The programmer writes instructions that:
#
# 1. Create an empty list.
# 2. Visit each temperature reading one at a time.
# 3. Check whether the reading is above 35°C.
# 4. If it is, add it to the list.
# 5. Print the final list.
#
# **Paradigm:** ____________________
#
# **Why?** ______________________________________________________
#
#
# ### **Scenario 2 — Data Analysis Toolkit**
#
# A data scientist frequently needs to clean datasets. Instead of repeating the same code, she creates:
#
# ```python
# remove_missing_values()
# normalize_data()
# calculate_mean()
# generate_report()
# ```
#
# Her main program solves problems by calling these reusable operations whenever they are needed.
#
# **Paradigm:** ____________________
#
# **Why?** ______________________________________________________
#
#
# ### **Scenario 3 — University Enrollment System**
#
# A development team is designing an enrollment system. They identify several important entities:
#
# ```text
# Student
# Course
# Instructor
# Enrollment
# ```
#
# Each entity stores information and has associated responsibilities. For example, a `Student` stores a name and student number and can `enroll()`, while a `Course` stores its course code and can `add_student()`.
#
# **Paradigm:** ____________________
#
# **Why?** ______________________________________________________
#
#
# ### **Scenario 4 — Transforming a Dataset**
#
# A programmer processes sales data as a sequence of transformations:
#
# ```text
# Raw Sales
#     ↓
# remove invalid records
#     ↓
# convert currencies
#     ↓
# calculate totals
#     ↓
# produce results
# ```
#
# Each operation accepts data and produces new data that becomes the input of the next operation. The programmer tries to avoid unnecessarily modifying the original data.
#
# **Paradigm:** ____________________
#
# **Why?** ______________________________________________________
#
#
# ### **Scenario 5 — Finding Qualified Students**
#
# Student information is stored in a database. The programmer wants the names of students whose grade is at least 90.
#
# Instead of writing instructions describing how the database should inspect every record, the programmer writes:
#
# ```sql
# SELECT name
# FROM students
# WHERE grade >= 90;
# ```
#
# The programmer specifies the **result that is wanted** and leaves the database system to determine how to retrieve it.
#
# **Paradigm:** ____________________
#
# **Why?** ______________________________________________________
#
#
# ### **Scenario 6 — Hospital Management System**
#
# A hospital system contains `Patient`, `Doctor`, and `Appointment` entities. A programmer creates a `Patient` that stores a patient's information and provides operations such as:
#
# ```text
# update_contact()
# schedule_appointment()
# view_medical_history()
# ```
#
# The programmer's design starts by asking:
#
# > “What entities exist in the hospital, what information should each contain, and what responsibilities should each have?”
#
# **Paradigm:** ____________________
#
# **Why?** ______________________________________________________
#
#
# ### **Scenario 7 — Calculating Final Grades**
#
# A programmer writes:
#
# ```python
# total = 0
#
# for grade in grades:
#     total = total + grade
#
# average = total / len(grades)
#
# if average >= 75:
#     print("Passed")
# else:
#     print("Failed")
# ```
#
# The solution focuses on variables whose values change as a sequence of instructions executes.
#
# **Paradigm:** ____________________
#
# **Why?** ______________________________________________________
#
#
# ### **Scenario 8 — Image Processing Pipeline**
#
# An application processes an image using several transformations:
#
# ```python
# result = resize(image)
# result = grayscale(result)
# result = sharpen(result)
# result = compress(result)
# ```
#
# The programmer begins thinking about how several transformations can be composed so that the output of one operation becomes the input of another.
#
# **Paradigm:** ____________________
#
# **Why?** ______________________________________________________
#
#
# ## Challenge: Same Problem, Different Thinking
#
# Consider this problem:
#
# > **A university needs a system that determines which students are eligible for the Dean's List based on their grades.**
#
# For each statement below, identify the paradigm reflected by the programmer's thinking.
#
# | Programmer's approach                                                                                                                | Paradigm   |
# | ------------------------------------------------------------------------------------------------------------------------------------ | ---------- |
# | A. “I'll loop through every student, calculate the average, check the condition, and append qualified students to a list.”           | __________ |
# | B. “I'll create functions such as `calculate_average()` and `is_eligible()`.”                                                        | __________ |
# | C. “I'll create `Student` and `Course` entities. Each student should know their grades and be able to determine their eligibility.”  | __________ |
# | D. “I'll transform the collection of students using functions that calculate averages and filter eligible students.”                 | __________ |
# | E. “I'll query the database for students satisfying the eligibility conditions and let the database determine how to retrieve them.” | __________ |
